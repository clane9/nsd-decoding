# %%
import pandas as pd

# %%
results = pd.read_json("results.jsonl", lines=True)

records = []
for _, row in results.iterrows():
    record = {
        "subs": row["args"]["subs"],
        "lr": row["args"]["lr"],
        "wd": row["args"]["wd"],
        "acc_train": row["acc_train"],
        "acc_val": row["acc_val"],
        "acc_test": row["acc_test"],
    }
    records.append(record)
df = pd.DataFrame.from_records(records)

print(df.shape)
df.head()
# Out:
# (84, 6)
#           subs      lr     wd  acc_train  acc_val  acc_test
# 0  0,1,2,5,6,7  0.0005  0.001     99.997   42.086    48.137
# 1  0,1,2,5,6,7  0.0005  0.010     75.442   41.816    48.654
# 2  0,1,2,5,6,7  0.0005  0.100     74.907   42.182    50.062
# 3  0,1,2,5,6,7  0.0010  0.001     74.080   42.125    49.917
# 4  0,1,2,5,6,7  0.0010  0.010     99.994   41.797    48.054

# %%
summary = []
for subs, group in df.groupby("subs"):
    idx = group["acc_val"].idxmax()
    summary.append(group.loc[idx])
summary = pd.DataFrame.from_records(summary)
summary
# Out:
#           subs      lr    wd  acc_train  acc_val  acc_test
# 0            0  0.0005  0.10     99.984   67.014    65.781
# 1  0,1,2,5,6,7  0.0100  0.10    100.000   42.915    48.944
# 2            1  0.0005  0.10    100.000   56.496    62.348
# 3            2  0.0050  0.01    100.000   49.944    59.448

# %%
summary_fmt = summary.copy()
summary_fmt = summary_fmt.loc[[1, 0, 2, 3], ["subs", "acc_val", "acc_test"]]
summary_fmt.columns = ["subjects", "val (testid)", "test (shared1k)"]
print(summary_fmt.to_markdown(index=False))
# Out:
# | subjects    |   val (testid) |   test (shared1k) |
# |:------------|---------------:|------------------:|
# | 0,1,2,5,6,7 |         42.915 |            48.944 |
# | 0           |         67.014 |            65.781 |
# | 1           |         56.496 |            62.348 |
# | 2           |         49.944 |            59.448 |
